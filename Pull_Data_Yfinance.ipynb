# %% [markdown]
# <a href="https://colab.research.google.com/github/FredLongo/MLDL_Project/blob/main/Pull_Data_Yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ----
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
ADM_PARAMS = {
    't': '96mo',
    'tickers': 'ADM'}

MSI_PARAMS = {
    't': '96mo',
    'tickers': 'MSI'}

XOM_PARAMS = {
    't': '96mo',
    'tickers': 'XOM'}

# %%
adm_data = yf.Tickers(ADM_PARAMS.get('tickers'))
msi_data = yf.Tickers(MSI_PARAMS.get('tickers'))
xom_data = yf.Tickers(XOM_PARAMS.get('tickers'))

print(adm_data)
print(msi_data)
print(xom_data)
# Out:
# yfinance.Tickers object <ADM>
# yfinance.Tickers object <MSI>
# yfinance.Tickers object <XOM>

# %%
hist = data.history(ADM_PARAMS.get('t'))
print(hist)   # view the dataframe

hist = data.history(MSI_PARAMS.get('t'))
print(hist)   # view the dataframe

hist = data.history(XOM_PARAMS.get('t'))
print(hist)   # view the dataframe
# Out:
# [*********************100%%**********************]  3 of 3 completed
# [*********************100%%**********************]  3 of 3 completed
# [                       0%%                      ]
# Price           Close                         Dividends                 High  \
# Ticker            ADM         MSI         XOM       ADM  MSI  XOM        ADM
# Date
# 2016-04-25  31.353506   66.162743   60.402672       0.0  0.0  0.0  31.513229
# 2016-04-26  31.728855   66.504471   60.610149       0.0  0.0  0.0  31.944481
# 2016-04-27  31.872606   66.627113   61.184212       0.0  0.0  0.0  32.016357
# 2016-04-28  32.000385   66.013763   60.886826       0.0  0.0  0.0  32.439621
# 2016-04-29  31.896572   65.882362   61.142723       0.0  0.0  0.0  32.032338
# ...               ...         ...         ...       ...  ...  ...        ...
# 2024-04-16  60.270000  340.109985  118.690002       0.0  0.0  0.0  60.720001
# 2024-04-17  60.419998  340.510010  118.629997       0.0  0.0  0.0  61.110001
# ...

# %%
# to normalize  (Closing price / First Closing price  ) -1

indexed = hist[['Close']] /  hist[['Close']].iloc[0] - 1

# %%
indexed  # This is our cumulated data seres
# Out:
# Price           Close
# Ticker            ADM         MSI         XOM
# Date
# 1980-04-21   0.000000    0.000000    0.000000
# 1980-04-22   0.115385    0.051359    0.035011
# 1980-04-23   0.057692    0.087612    0.039388
# 1980-04-24   0.091346    0.117825    0.037199
# 1980-04-25   0.115385    0.120845    0.045952
# ...               ...         ...         ...
# 2024-04-15  66.450696  146.579443  216.024945
# 2024-04-16  66.172067  147.246335  214.229706
# 2024-04-17  66.339242  147.420697  214.120894
# 2024-04-18  67.788120  146.963017  213.921422
# 2024-04-19  68.768894  147.045835  216.387615
#
# [11093 rows x 3 columns]

# %%
indexed.plot(figsize= (16,6))
plt.title('All Data')
plt.show()

# %%
hist.to_csv('Stock_out.csv')
